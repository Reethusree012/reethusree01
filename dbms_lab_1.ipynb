# %% [markdown]
# <a href="https://colab.research.google.com/github/Reethusree012/reethusree01/blob/master/dbms_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# d.reethusree(32191035038)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("VsemEsectionList.xlsx")

# %%
df
# Out:
#    IV Sem E Section Roll List    Unnamed: 1              Unnamed: 2
# 0                     Sl. No.   Roll Number            Student Name
# 1                           1  321910305001    PUDURU VAMSI KRISHNA
# 2                           2  321910305002         DHARANI SRINIJA
# 3                           3  321910305003     MUTTINENI AISHWARYA
# 4                           4  321910305004   NAGIREDDY JEEVANREDDY
# ..                        ...           ...                     ...
# 60                         60  321910305061  SAVARAPU JASPER PRINCE
# 61                        NaN           NaN                     NaN
# 62                        NaN          Boys                     NaN
# 63                        NaN         Girls                     NaN
# 64                        NaN         Total                     NaN
#
# [65 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# IV Sem E Section Roll List         Sl. No.
# Unnamed: 1                     Roll Number
# Unnamed: 2                    Student Name
# Name: 0, dtype: object

# %%
headers=df.iloc[0]
new_df=pd.DataFrame(df.values[1:61],columns=headers)

# %%
new_df
# Out:
# 0  Sl. No.   Roll Number                             Student Name
# 0        1  321910305001                     PUDURU VAMSI KRISHNA
# 1        2  321910305002                          DHARANI SRINIJA
# 2        3  321910305003                      MUTTINENI AISHWARYA
# 3        4  321910305004                    NAGIREDDY JEEVANREDDY
# 4        5  321910305005          SANKEPALLI CHENNA SANDEEP REDDY
# 5        6  321910305006                               NAVNEETH N
# 6        7  321910305007                    BYALLA CHANDRA SEKHER
# 7        8  321910305008                    SHAIK KHAJA KAIF AZAM
# 8        9  321910305009                ANIMALA VENKATA SAI VIDYA
# 9       10  321910305010                      GUTTIKONDA NIKHITHA
# 10      11  321910305011                         RAJAVARI THANUJA
# 11      12  321910305012                   ALLAM LAKSHMI NARAYANA
# 12      13  321910305013                       BOMMA SREE LAKSHMI
# ...

# %%
new_df['age']=np.random.randint(19,21,size=60,dtype=int)

# %%
new_df
# Out:
# 0  Sl. No.   Roll Number  ... age  old_branch
# 0        1  321910305001  ...  20         CSE
# 1        2  321910305002  ...  19         CSE
# 2        3  321910305003  ...  20         CSE
# 3        4  321910305004  ...  19         CSE
# 4        5  321910305005  ...  19         CSE
# 5        6  321910305006  ...  20         CSE
# 6        7  321910305007  ...  19         CSE
# 7        8  321910305008  ...  19         CSE
# 8        9  321910305009  ...  20         CSE
# 9       10  321910305010  ...  19         CSE
# 10      11  321910305011  ...  20         CSE
# 11      12  321910305012  ...  20         CSE
# 12      13  321910305013  ...  20         CSE
# 13      14  321910305015  ...  20         CSE
# 14      15  321910305016  ...  20         CSE
# 15      16  321910305017  ...  20         CSE
# 16      17  321910305018  ...  19         CSE
# 17      18  321910305019  ...  19         CSE
# 18      19  321910305020  ...  19         CSE
# ...

# %%
new_df['old_branch']=['CSE']*60

# %%
new_df
# Out:
# 0  Sl. No.   Roll Number  ... age  old_branch
# 0        1  321910305001  ...  20         CSE
# 1        2  321910305002  ...  19         CSE
# 2        3  321910305003  ...  20         CSE
# 3        4  321910305004  ...  19         CSE
# 4        5  321910305005  ...  19         CSE
# 5        6  321910305006  ...  20         CSE
# 6        7  321910305007  ...  19         CSE
# 7        8  321910305008  ...  19         CSE
# 8        9  321910305009  ...  20         CSE
# 9       10  321910305010  ...  19         CSE
# 10      11  321910305011  ...  20         CSE
# 11      12  321910305012  ...  20         CSE
# 12      13  321910305013  ...  20         CSE
# 13      14  321910305015  ...  20         CSE
# 14      15  321910305016  ...  20         CSE
# 15      16  321910305017  ...  20         CSE
# 16      17  321910305018  ...  19         CSE
# 17      18  321910305019  ...  19         CSE
# 18      19  321910305020  ...  19         CSE
# ...

# %%
new_df['new_branch']=['CSE']*25+['IT']*6+['ECE']*4+['CSE']*20+['MECH']*2+['CIVIL']*3

# %%
new_df
# Out:
# 0  Sl. No.   Roll Number  ... old_branch  new_branch
# 0        1  321910305001  ...        CSE         CSE
# 1        2  321910305002  ...        CSE         CSE
# 2        3  321910305003  ...        CSE         CSE
# 3        4  321910305004  ...        CSE         CSE
# 4        5  321910305005  ...        CSE         CSE
# 5        6  321910305006  ...        CSE         CSE
# 6        7  321910305007  ...        CSE         CSE
# 7        8  321910305008  ...        CSE         CSE
# 8        9  321910305009  ...        CSE         CSE
# 9       10  321910305010  ...        CSE         CSE
# 10      11  321910305011  ...        CSE         CSE
# 11      12  321910305012  ...        CSE         CSE
# 12      13  321910305013  ...        CSE         CSE
# 13      14  321910305015  ...        CSE         CSE
# 14      15  321910305016  ...        CSE         CSE
# 15      16  321910305017  ...        CSE         CSE
# 16      17  321910305018  ...        CSE         CSE
# ...

# %%
final_df = new_df[new_df['old_branch'] == new_df['new_branch']]

# %%
final_df
# Out:
# 0  Sl. No.   Roll Number  ... old_branch  new_branch
# 0        1  321910305001  ...        CSE         CSE
# 1        2  321910305002  ...        CSE         CSE
# 2        3  321910305003  ...        CSE         CSE
# 3        4  321910305004  ...        CSE         CSE
# 4        5  321910305005  ...        CSE         CSE
# 5        6  321910305006  ...        CSE         CSE
# 6        7  321910305007  ...        CSE         CSE
# 7        8  321910305008  ...        CSE         CSE
# 8        9  321910305009  ...        CSE         CSE
# 9       10  321910305010  ...        CSE         CSE
# 10      11  321910305011  ...        CSE         CSE
# 11      12  321910305012  ...        CSE         CSE
# 12      13  321910305013  ...        CSE         CSE
# 13      14  321910305015  ...        CSE         CSE
# 14      15  321910305016  ...        CSE         CSE
# 15      16  321910305017  ...        CSE         CSE
# 16      17  321910305018  ...        CSE         CSE
# ...

# %%
class age:
  def __init__(self,data):
    self.df = data
  def youngest(self):
    return self.df[self.df['age'] == self.df['age'].min()]['Student Name']
    values.tolest()
  def oldest(self):
    return self.df[self.df['age'] == self.df['age'].max()]['Student Name']
    values.tolist()
  def average_age(self):
    return int(self.df['age'].mean())
  def median_age(self):
    return int(self.df['age'].median())

# %%
d = age(final_df)

# %%
d.youngest()
# Out:
# 1                     DHARANI SRINIJA
# 3               NAGIREDDY JEEVANREDDY
# 4     SANKEPALLI CHENNA SANDEEP REDDY
# 6               BYALLA CHANDRA SEKHER
# 7               SHAIK KHAJA KAIF AZAM
# 9                 GUTTIKONDA NIKHITHA
# 16        THATHEKALVA OMPRAKASH REDDY
# 17                POTHURU SAI HEMANTH
# 18                       ARUN KUMAR M
# 19           RAMIREDDY MAHIDHAR REDDY
# 21                       POORNIMA D S
# 23                    C REVANTH REDDY
# 36              DEVIREDDY REETHU SREE
# 37                  GANGIMENI POLAPPA
# 38              CHAKKA VENKATA DINESH
# 41                       RAKESH REDDY
# 42                   U MANISH ADITHYA
# 45                     ANIL KUMAR B R
# 46                         BHUVAN A L
# 51                          SHRAVAN S
# 52               KOGILATHOTA AISWARYA
# 53                     KARRI SATHVIKA
# Name: Student Name, dtype: object

# %%
d.oldest()
# Out:
# 0                        PUDURU VAMSI KRISHNA
# 2                         MUTTINENI AISHWARYA
# 5                                  NAVNEETH N
# 8                   ANIMALA VENKATA SAI VIDYA
# 10                           RAJAVARI THANUJA
# 11                     ALLAM LAKSHMI NARAYANA
# 12                         BOMMA SREE LAKSHMI
# 13                  DUGGINENI AKHILA CHOWDARY
# 14                          CHEMBETI MANIDEEP
# 15                       JALADHI SAI VARSHINI
# 20                                     LAYA T
# 22    KUDUMULA MULAMMAGARI VENKATESWARA REDDY
# 24                  KURAPATI JAYA SAI KRISHNA
# 35                    CHEDELLA SUBRAMANYESWAR
# 39                       VANNELA PAVAN KALYAN
# 40                             MIDDI SREEDEVI
# 43                     BUSALA CHARAN SRI TEJA
# 44                                    RAMYA G
# 47                          MATAPATI VINEETHA
# 48                                 GOUTHAMI D
# ...

# %%
d.average_age()
# Out:
# 19

# %%
d.median_age()
# Out:
# 20
